# %% [markdown]
# <a href="https://colab.research.google.com/github/kimmjen/Tazan_Front/blob/kimmjen/DATA_KOSA%EC%97%AC%ED%96%89%EC%A7%80_ALL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/kosa
# Out:
# /content/drive/MyDrive/kosa

# %%
pwd
# Out:
# '/content/drive/MyDrive/kosa'

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import requests
import urllib

# %%
url = 'http://api.data.go.kr/openapi/tn_pubr_public_trrsrt_api'
# service_key = 'rsTYVlTlaH958PwqHiqchWIqBPwgVy6rGyGG%2FwouF7MfkyHdw%2Fo99gVovy6vaHXQ03zGWpDlhw%2Bw%2FalmCZJHyg%3D%3D'
params = '?' + urlencode({
    # 'serviceKey' : 'rsTYVlTlaH958PwqHiqchWIqBPwgVy6rGyGG%2FwouF7MfkyHdw%2Fo99gVovy6vaHXQ03zGWpDlhw%2Bw%2FalmCZJHyg%3D%3D',
    'serviceKey' : 'rsTYVlTlaH958PwqHiqchWIqBPwgVy6rGyGG/wouF7MfkyHdw/o99gVovy6vaHXQ03zGWpDlhw+w/almCZJHyg==',
    'pageNo' : '1',
    'numOfRows' : '640',
    'type' : 'json'
    # 'referenceDate' : ''
})

# %%
response = urlopen(url + params)
json_api = response.read().decode("utf-8")

# %%
json_api
# Out:
# '{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE","type":"json"},"body":{"items":[{"trrsrtNm":"임진각관광지","trrsrtSe":"관광지","rdnmadr":"경기도 파주시 문산읍 임진각로 177","lnmadr":"경기도 파주시 문산읍 사목리 494-1","latitude":"37.8893177","longitude":"126.740081","ar":"477894","cnvnncFclty":"관리사무실+관광안내매표소1층+화장실3동+홍보관1층+상황실2층+오수처리장1층+기반시설(도로+광장+주차장)","stayngInfo":"없음","mvmAmsmtFclty":"유원시설(평화랜드)+관광열차(평화열차)","recrtClturFclty":"기념비공원6.25납북자기념관망배단망향의노래비평화의 종각철마는달리고싶다아웅산위령탑장단콩전시관","hospitalityFclty":"없음","sportFclty":"없음","appnDate":"1991-01-28","aceptncCo":"50000","prkplceCo":"2091","trrsrtIntrcn":"서울에서 북서쪽으로 약 54km 떨어진 임진각은 6.25 전쟁의 비통한 한이 서려 있는 곳이다. 6,000평 대지 위에 지하 1층, 지상 3층의 임진각은 1972년에 북한 실향민을 위해 세워져 지금은 관광명소로 많이 알려져 있다. 이곳에는 평화와 환경의 중요성을 전달하는 경기평화센터가 있다. 또한, 철마는 달리고 싶다 철도중단점, 북한 실향민을 위한 망배단, 미얀마 아웅산 순국외교사절 위령탑, 한국전쟁의 대표 유산으로서 50여년 만에 개방이 된 자유의 다리와 한반도의 지령을 본딴 통일연못, 평화의 종, 미국군 참전기념비 등이 있는 통일안보 관광지이다. 더불어 남북교류 및 화해협력의 장소로 통일관련행사를 많이 치르고 있다. 판문점처럼 복잡한 허가절차를 필요로 하지 않는 관광지로서 경기도내에서 가장 외국인이 많이 찾는
# ...

# %%
import pandas as pd
from pandas.io.json import json_normalize
import json

json_file = json.loads(json_api)
# result_json_api = xmltodict.parse(json_api)

# %%
json_file
# Out:
# {'response': {'body': {'items': [{'aceptncCo': '50000',
#      'appnDate': '1991-01-28',
#      'ar': '477894',
#      'cnvnncFclty': '관리사무실+관광안내매표소1층+화장실3동+홍보관1층+상황실2층+오수처리장1층+기반시설(도로+광장+주차장)',
#      'hospitalityFclty': '없음',
#      'institutionNm': '파주시 시설관리공단',
#      'insttCode': '4060000',
#      'latitude': '37.8893177',
#      'lnmadr': '경기도 파주시 문산읍 사목리 494-1',
#      'longitude': '126.740081',
#      'mvmAmsmtFclty': '유원시설(평화랜드)+관광열차(평화열차)',
#      'phoneNumber': '031-950-1871',
#      'prkplceCo': '2091',
#      'rdnmadr': '경기도 파주시 문산읍 임진각로 177',
#      'recrtClturFclty': '기념비공원6.25납북자기념관망배단망향의노래비평화의 종각철마는달리고싶다아웅산위령탑장단콩전시관',
#      'referenceDate': '2021-03-30',
#      'sportFclty': '없음',
#      'stayngInfo': '없음',
# ...

# %% [markdown]
# {'response': {'body': {'items': [{'auspcInstt':

# %%
df=json_normalize(json_file['response']['body']['items'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      trrsrtNm trrsrtSe  ... referenceDate insttCode
# 0      임진각관광지      관광지  ...    2021-03-30   4060000
# 1       공릉관광지      관광지  ...    2021-03-30   4060000
# 2    방화동가족휴가촌      관광지  ...    2021-04-08   4750000
# 3       송정관광지      관광지  ...    2021-03-31   5430000
# 4     예당국민관광지      관광지  ...    2021-05-25   4610000
# ..        ...      ...  ...           ...       ...
# 635    부석사관광지      관광지  ...    2020-07-20   5090000
# 636   산토끼노래동산      관광지  ...    2020-07-20   5410000
# 637    우장춘기념관      관광지  ...    2020-12-08   3300000
# 638   장영실과학동산      관광지  ...    2020-12-08   3300000
# 639   박차정의사생가      관광지  ...    2020-12-08   3300000
#
# [640 rows x 21 columns]

# %% [markdown]
# trrsrtNm
# trrsrtSe
# rdnmadr
# lnmadr
# latitude
# longitude	ar
# cnvnncFclty
# stayngInfo
# mvmAmsmtFclty
# recrtClturFclty
# hospitalityFclty
# sportFclty
# appnDate
# aceptncCo
# prkplceCo
# trrsrtIntrcn
# phoneNumber
# institutionNm
# referenceDate
# insttCode

# %%
df.rename(columns = {
    "trrsrtNm":"관광지명", 
    "trrsrtSe":"관광지구분", 
    "rdnmadr" : "소재지도로명주소", 
    "lnmadr" : "소재지지번주소",
    "latitude"	: "위도",
    "longitude"	: "경도",
    "ar" : "면적",
    "cnvnncFclty" : "공공편익시설정보",
    "stayngInfo" : "숙박시설정보",
    "mvmAmsmtFclty" : "운동및오락시설정보",
    "recrtClturFclty" : "휴양및문화시설정보",
    "hospitalityFclty" : "접객시설정보",
    "sportFclty" : "지원시설정보",
    "appnDate" : "지정일자",
    "aceptncCo": "수용인원수",
    "prkplceCo" : "주차가능수",
    "trrsrtIntrcn" : "관광지소개",
    "phoneNumber" : "관리기관전화번호",
    "institutionNm" : "관리기관명",
    "referenceDate" : "데이터기준일자",
    "instt_code" : "제공기관코드",
    "instt_nm" : "제공기관기관명"
    }, inplace= True)

# %% [markdown]
# |||
# |--|--|
# |pageNo|	*페이지 번호|
# |numOfRows|	*한 페이지 결과 수|
# |type	|json|
#    |fstvlNm	|축제명|
#    |opar	|개최장소|
#    |fstvlStartDate	|축제시작일자|
#    |fstvlEndDate	|축제종료일자|
#    |fstvlCo	|축제내용|
#    |mnnst	|주관기관|
#    |auspcInstt	|주최기관|
#    |suprtInstt	|후원기관|
#    |phoneNumber	|전화번호|
#    |homepageUrl	|홈페이지주소|
#    |relateInfo	|관련정보|
#    |rdnmadr	|소재지도로명주소|
#    |lnmadr	|소재지지번주소|
#    |latitude	|위도|
#    |longitude	|경도|
#    |referenceDate	|데이터기준일자|
#    |instt_code	|제공기관코드|
#    |instt_nm	|제공기관기관명|

# %%
df
# Out:
#          관광지명 관광지구분  ...     데이터기준일자 insttCode
# 0      임진각관광지   관광지  ...  2021-03-30   4060000
# 1       공릉관광지   관광지  ...  2021-03-30   4060000
# 2    방화동가족휴가촌   관광지  ...  2021-04-08   4750000
# 3       송정관광지   관광지  ...  2021-03-31   5430000
# 4     예당국민관광지   관광지  ...  2021-05-25   4610000
# ..        ...   ...  ...         ...       ...
# 635    부석사관광지   관광지  ...  2020-07-20   5090000
# 636   산토끼노래동산   관광지  ...  2020-07-20   5410000
# 637    우장춘기념관   관광지  ...  2020-12-08   3300000
# 638   장영실과학동산   관광지  ...  2020-12-08   3300000
# 639   박차정의사생가   관광지  ...  2020-12-08   3300000
#
# [640 rows x 21 columns]

# %%
df.to_csv('tour.csv')

# %%
df.to_csv('tour.txt')

# %%
int Date =[]
fstvlNm	= []#축제명
opar = []#개최장소
fstvlStartDate = []#축제시작일자
fstvlEndDate = []#축제종료일자
fstvlCo	= []#축제내용
mnnst	= []#주관기관
auspcInstt = []#주최기관
suprtInstt = []#후원기관
phoneNumber = []#전화번호
homepageUrl = []#홈페이지주소
relateInfo = []#관련정보
rdnmadr = []#소재지도로명주소
lnmadr = []#소재지지번주소
latitude = []#위도
longitude= []#경도
# Out:
#   File "<ipython-input-29-288cffe445a0>", line 1
#     int Date =[]
#            ^
# SyntaxError: invalid syntax

# %%
for i in df:
  Date.append(i)
  ftvlNm.append(i['fstvlNm'])
  opar.append(i['opar'])
  fstvlStartDate.append(i['fstvlStartDate'])
  fstvlEndDate.append(i['fstvlEndDate'])
  fstvlCo.append(i['fstvlCo'])
  mnnst.append(i['mnnst'])
  auspcInstt.append(i['auspcInstt'])
  suprtInstt.append(i['suprtInstt'])
  phoneNumber.append(i['phoneNumber'])
  homepageUrl.append(i['homepageUrl'])
  relateInfo.append(i['relateInfo'])
  rdnmadr.append(i['rdnmadr'])
  lnmadr.append(i['lnmadr'])
  latitude.append(i['latitude'])
  longitude.append(i['longitude'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-e5b4a868e87e> in <module>()
#       1 for i in df:
# ----> 2   Date.append(i)
#       3   ftvlNm.append(i['fstvlNm'])
#       4   opar.append(i['opar'])
#       5   fstvlStartDate.append(i['fstvlStartDate'])
#
# NameError: name 'Date' is not defined
